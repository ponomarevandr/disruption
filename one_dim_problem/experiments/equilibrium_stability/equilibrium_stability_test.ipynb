# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams.update({'font.size': 14})

import sys
sys.path.append("../../scripts")
import importlib

import model
importlib.reload(model)
from model import Model, model_from_file

import model_plot
importlib.reload(model_plot)
from model_plot import model_plot

import norms
importlib.reload(norms)
from norms import norm_continuous, norm_L2

# %matplotlib inline

# %%
model = model_from_file('equilibrium_stability/values_1_0.csv')
model_plot(model, [0.0, 0.5, 1], False, xlim=[10, 40], ylim=[0.008, 0.011])

# %%
model = model_from_file('equilibrium_stability/values_1_1.csv')
model_plot(model, [0.0, 0.05, 0.1], False)

# %%
model = model_from_file('equilibrium_stability/values_2_0.csv')
model_plot(model, [0.0, 0.05, 0.1], False)

# %%
model = model_from_file('equilibrium_stability/values_2_05.csv')
model_plot(model, [0.0, 0.05, 0.1], False)

# %%
model = model_from_file('equilibrium_stability/values_2_1.csv')
model_plot(model, [0.0, 0.05, 0.1], False)

# %%
model = model_from_file('equilibrium_stability/values_3_0.csv')
model_plot(model, [0.0, 0.01, 0.02], False)

# %%
model = model_from_file('equilibrium_stability/values_3_1.csv')
model_plot(model, [0.0, 0.05, 0.1], False)
