# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams.update({'font.size': 16})

import sys
sys.path.append("../../scripts")
import importlib

import model
importlib.reload(model)
from model import Model, model_from_file

import model_plot
importlib.reload(model_plot)
from model_plot import model_plot

# %matplotlib inline

# %%
model_density_electrical = model_from_file('data/model_density_electrical.csv')
model_plot(model_density_electrical, [0, 0.1, 0.3, 0.4, 0.5, 0.55, 0.6, 0.7, 0.8, 1], False)

# %%
model_density_inner = model_from_file('data/model_density_inner.csv')
model_plot(model_density_inner, [0, 0.1, 0.3, 0.4, 0.5, 0.55, 0.6, 0.7, 0.8, 1], False)

# %%
model_density_border = model_from_file('data/model_density_border.csv')
model_plot(model_density_border, [0, 0.1, 0.3, 0.4, 0.5, 0.55, 0.6, 0.7, 0.8, 1], False)

# %%
def total_energy_plot(model):
    ts = np.arange(model.df_phi.shape[0]) * model.params['dt_data']
    plt.plot(ts, model.phi[:, 0])
    plt.show()

# %%
model_total = model_from_file('data/model_total.csv')
total_energy_plot(model_total)
