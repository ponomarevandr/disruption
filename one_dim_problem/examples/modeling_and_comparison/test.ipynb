# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys
sys.path.append("../../scripts")
import importlib

import model
importlib.reload(model)
from model import Model, model_from_file

import model_plot
importlib.reload(model_plot)
from model_plot import model_plot

import norms
importlib.reload(norms)
from norms import norm_continuous, norm_L2

import os

# %matplotlib inline

# %%
model = model_from_file('../../bin/experiment.csv')
model_plot(model, np.linspace(0, 1, 11))

# %%
model_2 = model_from_file('../../bin/experiment_2.csv')
model_3 = model_from_file('../../bin/experiment_3.csv')
model_skipped = model_from_file('../../bin/experiment_skipped.csv')

# %%
print(norm_continuous(model, model_2))
print(norm_continuous(model, model_3))
print(norm_continuous(model, model_skipped))
print(norm_continuous(model_2, model_3))
# Out:
# 0.99709987809
# 0.01137876900000001
# 0.0
# 0.99710565581

# %%
print(norm_L2(model, model_2))
print(norm_L2(model, model_3))
print(norm_L2(model, model_skipped))
print(norm_L2(model_2, model_3))
# Out:
# 0.71679430270024
# 0.0017365284431216561
# 0.0
# 0.7172281424919215
