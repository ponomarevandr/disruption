# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys
sys.path.append("../../scripts")
import importlib

import model
importlib.reload(model)
from model import Model

import model_plot
importlib.reload(model_plot)
from model_plot import model_plot

import os

# %matplotlib inline

# %%
model = Model()
model.from_file('../../bin/experiment.csv')
model_plot(model, np.linspace(0, 0.1, 10))
