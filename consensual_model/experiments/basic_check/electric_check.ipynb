# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

from math import sqrt

import sys
sys.path.append("../../scripts")

from model import Model, model_from_file
from model_plot import model_plot
from norms import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_dir = 'data_electric/'

# %%
model = model_from_file(data_dir + 'model.csv')

# %%
model_plot(model, [0, 1e-5, 5e-5, 2e-4, 1e-3, 2e-2], figsize=(9, 6))

# %%
E_natural = 1.0 / model.params['l'] * sqrt(
    2.0 * model.params['Gamma'] * model.params['delta'] / model.params['eps_0']
)
E_natural
# Out:
# 177087.54896942922

# %%
q_transition = 2.0 * model.params['L'] / model.params['l'] * sqrt(
    model.params['eps_0'] * model.params['delta'] * model.params['Gamma']
)
q_transition
# Out:
# 1.9016631170375053e-10

# %%
print(model.E[0], model.E[-1])
print(E_natural * sqrt(2.0))
# Out:
# 678564.554 244391.379
# 250439.61347997643

# %%
plt.figure(figsize=(9, 6))
plt.xlim([-1e-5, 1e-3])
plt.ylim([0, model.E[0] * 1.02])
plt.plot(model.ts, model.E)
plt.show()
