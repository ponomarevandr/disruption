# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams.update({'font.size': 12})

import sys
sys.path.append("../../scripts")
import importlib

import model
importlib.reload(model)
from model import Model, model_from_file

import model_plot
importlib.reload(model_plot)
from model_plot import model_plot

import norms
importlib.reload(norms)
from norms import *

# %matplotlib inline

# %%
model_100 = model_from_file('../../bin/model_100.csv')
model_plot(model_100, [0, 0.5, 1, 6], figsize=(8, 5), xlim=[-0.1, 3])

# %%
model_100_p = model_from_file('../../bin/model_100_p.csv')
model_plot(model_100_p, [0, 0.5, 1, 6], figsize=(8, 5), xlim=[-0.1, 3])

# %%
model_100_bi = model_from_file('../../bin/model_100_bi.csv')
model_plot(model_100_bi, [0, 0.5, 1, 6], figsize=(8, 5), xlim=[-0.1, 3])
