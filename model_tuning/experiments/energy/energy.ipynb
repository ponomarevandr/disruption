# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

import sys
sys.path.append("../../scripts")
import importlib

import model
importlib.reload(model)
from model import Model, model_from_file

import model_plot
importlib.reload(model_plot)
from model_plot import model_plot

# %matplotlib inline

# %% [markdown]
# ## Типичное решение

# %%
model = model_from_file('../../bin/model.csv')
model_plot(model, [0, 0.2, 0.3, 0.4, 0.5, 0.55, 0.6, 0.7, 0.8, 1])

# %% [markdown]
# ## Плотности трех видов энергии

# %%
model_electrical = model_from_file('../../bin/model_electrical.csv')
model_plot(model_electrical, [0, 0.2, 0.3, 0.4, 0.5, 0.55, 0.6, 0.7, 0.8, 1])

# %%
model_border = model_from_file('../../bin/model_border.csv')
model_plot(model_border, [0, 0.2, 0.3, 0.4, 0.5, 0.55, 0.6, 0.7, 0.8, 1])

# %%
model_inner = model_from_file('../../bin/model_inner.csv')
model_plot(model_inner, [0, 0.2, 0.3, 0.4, 0.5, 0.55, 0.6, 0.7, 0.8, 1])

# %% [markdown]
# ## Зависимости трех видов энергии от времени

# %%
model_energy = model_from_file('../../bin/model_energy.csv')

# %%
plt.figure(figsize=(11, 6))
plt.plot(model_energy.ts, model_energy._energy_electrical)
plt.show()

# %%
plt.figure(figsize=(11, 6))
plt.plot(model_energy.ts, model_energy._energy_border)
plt.show()

# %%
plt.figure(figsize=(11, 6))
plt.plot(model_energy.ts, model_energy._energy_inner)
plt.show()
